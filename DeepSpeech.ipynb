# %% [markdown]
# ## Research Project Description
#
# This project will investigate the evolution of neural networks and their performance, through things such as hyperparameters, commits and technology used to train the networks. The primary method as of now is to use Github to scrape releases and commits.

# %% [markdown]
# ### Imports

# %%
import requests as r
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from tools import *

# %% [markdown]
# You will need a .env file with your username and token from Github.

# %%
from dotenv import load_dotenv
from os import environ
load_dotenv()

# %% [markdown]
# ## Repository Scraping
#
# We may use the Github API to request information from repositories such as:
#
#
# - Commit information (includes messages and links to diffs)
# - Release information
# - Stars, and other metrics
#
# For now, our repository of interest is Mozilla/DeepSpeech, which has over 104 releases.

# %%
g = Github(environ['user'],environ['token'])

# %% [markdown]
# Refer to `tools.py` for information on the class for Github scraping. Note that certain parameters, such as page number and the amount per page are passed as requests which is used for pagination.

# %%
g.get_releases("mozilla/DeepSpeech", {'page':1,'per_page':100}).json()[-1].keys()
# Out:
# dict_keys(['url', 'assets_url', 'upload_url', 'html_url', 'id', 'author', 'node_id', 'tag_name', 'target_commitish', 'name', 'draft', 'prerelease', 'created_at', 'published_at', 'assets', 'tarball_url', 'zipball_url', 'body'])

# %% [markdown]
# As of writing this document, there are 104 releases, so two scrapes sufficess to obtain all the release information. We then extract the columns of interest.

# %%
releases = g.get_releases("mozilla/DeepSpeech", {'page':1,'per_page':100}).json()+g.get_releases("mozilla/DeepSpeech", {'page':2,'per_page':100}).json()


# Get and store important information on releases
releases_df = pd.DataFrame(releases).drop([
    'reactions','zipball_url','tarball_url',
    'assets','created_at','draft','assets_url',
    'upload_url','author','node_id',
    'target_commitish','url','id'],axis=1)
releases_df['date'] = pd.to_datetime(releases_df['published_at'])
releases_df.to_pickle('data/deepspeech_releases.pkl')
releases_df
# Out:
#                                               html_url         tag_name  \
# 0    https://github.com/mozilla/DeepSpeech/releases...  v0.10.0-alpha.3
# 1    https://github.com/mozilla/DeepSpeech/releases...           v0.9.3
# 2    https://github.com/mozilla/DeepSpeech/releases...           v0.9.2
# 3    https://github.com/mozilla/DeepSpeech/releases...           v0.9.1
# 4    https://github.com/mozilla/DeepSpeech/releases...  v0.9.0-alpha.12
# ..                                                 ...              ...
# 100  https://github.com/mozilla/DeepSpeech/releases...   v0.2.1-alpha.0
# 101  https://github.com/mozilla/DeepSpeech/releases...  v0.2.0-alpha.10
# 102  https://github.com/mozilla/DeepSpeech/releases...           v0.2.0
# 103  https://github.com/mozilla/DeepSpeech/releases...           v0.1.1
# 104  https://github.com/mozilla/DeepSpeech/releases...           v0.1.0
#
#                   name  prerelease          published_at  \
# 0      v0.10.0-alpha.3        True  2020-12-19T10:13:23Z
# 1     DeepSpeech 0.9.3       False  2020-12-10T15:58:47Z
# 2     DeepSpeech 0.9.2       False  2020-12-03T16:40:18Z
# 3      DeepSpech 0.9.1       False  2020-11-04T16:56:50Z
# 4      v0.9.0-alpha.12        True  2020-10-30T17:17:02Z
# ..                 ...         ...                   ...
# 100     v0.2.1-alpha.0        True  2018-09-26T11:35:33Z
# 101    v0.2.0-alpha.10        True  2018-09-18T15:01:36Z
# 102  Deep Speech 0.2.0       False  2018-09-18T22:14:11Z
# 103  Deep Speech 0.1.1       False  2018-09-18T12:15:21Z
# 104  Deep Speech 0.1.0       False  2017-11-24T15:39:42Z
#
#                                                   body
# 0
# 1    # General\r\n\r\nThis is the 0.9.3 release of ...
# 2    # General\r\n\r\nThis is the 0.9.2 release of ...
# 3    # General\r\n\r\nThis is the 0.9.1 release of ...
# 4
# ..                                                 ...
# 100
# 101
# 102  # General\r\n\r\nThis is the 0.2.0 release of ...
# 103  # General\r\n\r\nThis is the 0.1.1 release of ...
# 104  # General\r\n\r\nThis is the initial release o...
#
# [105 rows x 6 columns]

# %% [markdown]
# We repeat the process for the commits. There are around 3500 commits.

# %%
commits = [g.get_commits('mozilla/DeepSpeech',{'page':x+1,'per_page':100}).json() for x in range(34)]
len(flatten(commits))

# %%
commits_df = pd.DataFrame([{'name':commit['commit']['author']['name'],
'date':commit['commit']['author']['date'], 
'html_url':commit['html_url'], 
'message': commit['commit']['message']} for commit in flatten(commits)])
commits_df['date'] = pd.to_datetime(commits_df['date'])
commits_df = commits_df.sort_values(by="date")
commits_df
# Out:
#                 name                      date  \
# 3225   Reuben Morais 2016-10-20 18:27:12+00:00
# 3388      Chris Lord 2016-10-26 15:13:49+00:00
# 3224   Reuben Morais 2016-10-27 18:08:14+00:00
# 3189     Andre Natal 2016-10-29 22:21:01+00:00
# 3190     Andre Natal 2016-10-29 22:21:01+00:00
# ...              ...                       ...
# 4             lissyx 2021-05-13 16:09:11+00:00
# 3             lissyx 2021-07-30 18:50:45+00:00
# 2             lissyx 2021-07-30 18:50:58+00:00
# 1     Daniel Tinazzi 2021-11-17 13:20:19+00:00
# 0             lissyx 2021-11-17 17:52:52+00:00
#
#                                                html_url  \
# 3225  https://github.com/mozilla/DeepSpeech/commit/c...
# 3388  https://github.com/mozilla/DeepSpeech/commit/2...
# 3224  https://github.com/mozilla/DeepSpeech/commit/d...
# 3189  https://github.com/mozilla/DeepSpeech/commit/c...
# 3190  https://github.com/mozilla/DeepSpeech/commit/5...
# ...                                                 ...
# 4     https://github.com/mozilla/DeepSpeech/commit/9...
# 3     https://github.com/mozilla/DeepSpeech/commit/f...
# 2     https://github.com/mozilla/DeepSpeech/commit/7...
# 1     https://github.com/mozilla/DeepSpeech/commit/4...
# 0     https://github.com/mozilla/DeepSpeech/commit/a...
#
#                                                 message
# 3225                   Implement Fisher corpus importer
# 3388  Use reshape/unpack to remove dependency on n_s...
# 3224  Address review comments and do further filteri...
# 3189                               Switchboard importer
# 3190                               Switchboard importer
# ...                                                 ...
# 4     Merge pull request #3647 from mozilla/ftyers-p...
# 3                                        Update conf.py
# 2     Merge pull request #3674 from mozilla/lissyx-p...
# 1     Fixed M-AILABS broken link\n\nI replaced the b...
# 0     Merge pull request #3703 from danieltinazzi/ma...
#
# [3400 rows x 4 columns]

# %% [markdown]
# ### Scrapable Data from Releases
#
# For any proper release, there is a standard pattern in the hyperparameters section that contains useful information. Employ a regex pattern to target all phrases of the form " * `blah` blahblah \r\n" then turn the options into a dictionary.
# Important values to tabulate are:
#
# - default_stddev
# - dev_batch_size
# - dev_files
# - epochs
# -  train_files
# - n_hidden
# - lm_alpha
# - lm_beta
# - train_batch_size
# - test_batch_size
#
# 'train_batch_size', 'dev_batch_size', 'test_batch_size', 'n_hidden', 'learning_rate', 'dropout_rate', 'epochs', 'lm_alpha', 'lm_beta'

# %%
releases_df['hyperparams'] = releases_df[releases_df['body']!='']['body'].str.findall('[*] `(.{2,}?)`(.{2,}?)\r\n').apply(tup_dict, filter=imp_hyperparams)

# %%
releases_df[releases_df['body']!=''][['name','published_at','hyperparams']]
# Out:
#                   name          published_at  \
# 1     DeepSpeech 0.9.3  2020-12-10T15:58:47Z
# 2     DeepSpeech 0.9.2  2020-12-03T16:40:18Z
# 3      DeepSpech 0.9.1  2020-11-04T16:56:50Z
# 6      DeepSpech 0.9.0  2020-11-02T13:07:03Z
# 10    DeepSpeech 0.8.2  2020-08-22T14:38:12Z
# 13    DeepSpeech 0.8.1  2020-08-11T08:25:48Z
# 16    DeepSpeech 0.8.0  2020-07-30T17:16:00Z
# 41    DeepSpeech 0.7.4  2020-06-18T14:57:08Z
# 43    DeepSpeech 0.7.3  2020-06-04T09:29:32Z
# 47    DeepSpeech 0.7.1  2020-05-12T15:31:11Z
# 52    DeepSpeech 0.7.0  2020-04-24T16:17:29Z
# 58    DeepSpeech 0.6.1  2020-01-10T17:12:08Z
# 66    DeepSpeech 0.6.0  2019-12-03T17:18:08Z
# 75    DeepSpeech 0.5.1  2019-06-20T17:27:39Z
# 77   Deep Speech 0.5.0  2019-06-11T15:25:34Z
# 89   Deep Speech 0.4.1  2019-01-10T14:47:43Z
# 93   Deep Speech 0.4.0  2019-01-10T14:49:55Z
# 97   Deep Speech 0.3.0  2018-10-23T15:58:49Z
# 102  Deep Speech 0.2.0  2018-09-18T22:14:11Z
# 103  Deep Speech 0.1.1  2018-09-18T12:15:21Z
# 104  Deep Speech 0.1.0  2017-11-24T15:39:42Z
#
#                                            hyperparams
# 1    {'train_batch_size': ' 128', 'dev_batch_size':...
# 2    {'train_batch_size': ' 128', 'dev_batch_size':...
# 3    {'train_batch_size': ' 128', 'dev_batch_size':...
# 6    {'train_batch_size': ' 128', 'dev_batch_size':...
# 10   {'train_batch_size': ' 128', 'dev_batch_size':...
# 13   {'train_batch_size': ' 128', 'dev_batch_size':...
# 16   {'train_batch_size': ' 128', 'dev_batch_size':...
# 41   {'train_batch_size': ' 128', 'dev_batch_size':...
# 43   {'train_batch_size': ' 128', 'dev_batch_size':...
# 47   {'train_batch_size': ' 128', 'dev_batch_size':...
# 52   {'train_batch_size': ' 128', 'dev_batch_size':...
# 58   {'train_batch_size': ' 128', 'dev_batch_size':...
# 66   {'train_batch_size': ' 128', 'dev_batch_size':...
# 75   {'train_batch_size': ' 24', 'dev_batch_size': ...
# 77   {'train_batch_size': ' 24', 'dev_batch_size': ...
# 89   {'train_batch_size': ' 24', 'dev_batch_size': ...
# 93   {'train_batch_size': ' 24', 'dev_batch_size': ...
# 97   {'train_batch_size': ' 24', 'dev_batch_size': ...
# 102  {'train_batch_size': ' 24', 'dev_batch_size': ...
# 103  {'train_batch_size': ' 12', 'dev_batch_size': ...
# 104                                                 {}

# %% [markdown]
# And so, we have the information of 21 releases with their hyperparameters. Note, that there is a lot more information to uncover within release messages.
